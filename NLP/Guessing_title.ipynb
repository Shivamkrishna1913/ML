# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus1="Artificial intelligence (AI) is transforming the healthcare industry, offering new possibilities for diagnosis, treatment, and patient care. AI-driven technologies, such as machine learning algorithms, are capable of analyzing vast amounts of medical data to identify patterns and make predictions that can assist healthcare professionals in making informed decisions. For example, AI is being used to detect diseases like cancer at earlier stages by analyzing medical images more accurately and quickly than traditional methods. This early detection can significantly improve patient outcomes by enabling prompt intervention.Moreover, AI is revolutionizing personalized medicine by tailoring treatments to individual patients based on their genetic profiles, lifestyle, and other factors. By analyzing data from various sources, AI can suggest the most effective treatment plans, reducing the trial-and-error approach often seen in traditional medicine. Additionally, AI-powered chatbots and virtual assistants are enhancing patient engagement and providing support for routine tasks such as scheduling appointments, reminding patients to take their medications, and answering basic health-related questions.Despite its benefits, the integration of AI in healthcare also raises ethical and practical concerns. Issues such as data privacy, the potential for algorithmic bias, and the need for human oversight in decision-making processes are critical considerations that must be addressed. Ensuring that AI systems are transparent, fair, and secure is essential to gaining the trust of both healthcare providers and patients.In conclusion, AI has the potential to significantly improve healthcare by enabling more accurate diagnoses, personalized treatments, and efficient patient care. However, careful consideration of the ethical and practical challenges associated with its use is crucial for its successful implementation. As AI continues to evolve, it is likely to play an increasingly central role in shaping the future of healthcare."
corpus2="Renewable energy sources, such as solar, wind, and hydropower, are playing a pivotal role in the global effort to combat climate change. Unlike fossil fuels, which release harmful greenhouse gases into the atmosphere when burned, renewable energy sources generate electricity without emitting carbon dioxide or other pollutants. This makes them a key component of strategies aimed at reducing the carbon footprint and mitigating the effects of global warming.Solar power, one of the most widely adopted forms of renewable energy, harnesses the sun's energy through photovoltaic cells to generate electricity. With advancements in technology, the efficiency and affordability of solar panels have improved significantly, making solar energy accessible to more people and businesses around the world. Similarly, wind power has seen substantial growth, particularly in countries with abundant wind resources. Wind turbines convert kinetic energy from the wind into electrical power, providing a clean and sustainable energy source."
corpus3="Mental health awareness is increasingly recognized as a crucial aspect of overall well-being, with a growing understanding of the impact that mental health has on individuals, families, and communities. Mental health encompasses a range of conditions, including depression, anxiety, bipolar disorder, and schizophrenia, which can affect a person's thoughts, feelings, and behavior. Despite its prevalence, mental health has often been stigmatized, leading to barriers in seeking help and support.Raising awareness about mental health is essential for several reasons. First, it helps to reduce the stigma and discrimination that individuals with mental health conditions often face. By promoting open conversations and educating the public, society can foster a more supportive environment where people feel comfortable seeking help. This is particularly important as untreated mental health issues can lead to severe consequences, including substance abuse, chronic illness, and suicide."

# %%
word_freq1={}
word_freq2={}
word_freq3={}

# %%
for word in word_tokenize(corpus1):
  word=word.lower()
  if word not in stopwords.words('english') and len(word)>=2:
      word_freq1[word]= 0
for word in word_tokenize(corpus1):
  word=word.lower()
  if word not in stopwords.words('english') and len(word)>=2:
      word_freq1[word]+=1

# %%
import pandas as pd
data=[]
for word in word_freq1:
  data.append([word,word_freq1[word]])
data = pd.DataFrame(data,columns=['Word','Frequency']).sort_values(by='Frequency',ascending=False)
data.head()
# Out:
#           Word  Frequency
# 2           ai          8
# 4   healthcare          6
# 11     patient          4
# 19   analyzing          3
# 23        data          3

# %% [markdown]
# Conclusion : Tile should be "Ai in healthcare".
